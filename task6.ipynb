# %% [markdown]
# ## Задание 6

# %%
string_one = input("Введите строку: ")

# Разделяем строку на список слов
words = string.split(", ")

# Преобразуем список в множество для удаления повторяющихся слов
unique_words = set(words)

# Сортируем множество и преобразуем его обратно в список
sorted_unique_words = sorted(unique_words)

# Соединяем отсортированные слова в строку с разделителем ", "
result = ", ".join(sorted_unique_words)

# Выводим результат
print(result)
# Out:
# Введите строку: Три, четверти, своего, дохода, он, расходовал, на, питание, а, одну, четверть, на, костюмы, Дон, Кихот, жил, в, доме, со, своей, молодой, племянницей, и, двумя, слугами, жена, или, дети, не, упоминаются, в, свои, годы, он, отличался, отменным, здоровьем, рано, вставал, и, увлекался, охотой, Однако, в, какой-то, момент, своей, жизни, он, настолько, увлёкся, рыцарскими, романами, что, охота, и, все, прочие, занятия, отошли, для, него, на, второй, план, Тогда, он, стал, одержим, идеей, стать, странствующим, рыцарем
# ...

# %%
string = input("Введите строку: ")
words = string.split(", ")
unique_words = sorted(set(words))
output_str = ", ".join(unique_words)
print(output_str)
# Out:
# Введите строку: Три, четверти, своего, дохода, он, расходовал, на, питание, а, одну, четверть, на, костюмы, Дон, Кихот, жил, в, доме, со, своей, молодой, племянницей, и, двумя, слугами, жена, или, дети, не, упоминаются, в, свои, годы, он, отличался, отменным, здоровьем, рано, вставал, и, увлекался, охотой, Однако, в, какой-то, момент, своей, жизни, он, настолько, увлёкся, рыцарскими, романами, что, охота, и, все, прочие, занятия, отошли, для, него, на, второй, план, Тогда, он, стал, одержим, идеей, стать, странствующим, рыцарем
# ...
